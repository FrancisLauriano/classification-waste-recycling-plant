# %% [markdown]
# # 🧠 Classificação de Resíduos Recicláveis com ResNet50 e Validação Cruzada

# %% [markdown]
# ## ♻️ Introdução
#
# A crescente geração de resíduos sólidos urbanos impõe desafios significativos à gestão ambiental e à sustentabilidade das cidades. Entre esses resíduos, os **materiais recicláveis** – como plásticos, vidros, papéis, metais e embalagens em geral – representam uma fração considerável e possuem grande potencial de revalorização por meio da coleta seletiva e da reciclagem (He & Garcia, 2009).
#
# Em ambientes urbanos e industriais, a **usina de triagem de resíduos recicláveis** desempenha um papel crucial nesse processo. Nesses centros, os resíduos são separados, classificados e direcionados para reaproveitamento. No entanto, essa triagem ainda é em grande parte manual, **suscetível a erros humanos, baixa produtividade e condições insalubres de trabalho** (Pan & Yang, 2010; Sammut & Webb, 2010).
#
# É nesse contexto que surgem as soluções baseadas em **Machine Learning (ML)** e **Visão Computacional**, com potencial de **automatizar a identificação e classificação de resíduos recicláveis**. O uso de modelos de aprendizado profundo (deep learning), como redes neurais convolucionais, permite que sistemas sejam treinados para reconhecer tipos de resíduos com base em milhares de imagens, tornando o processo **mais rápido, preciso e escalável** (He et al., 2016; Shorten & Khoshgoftaar, 2019).
#
# ### 💡 Machine Learning na Indústria
#
# A aplicação de **Machine Learning na indústria** vem se consolidando como uma das frentes mais promissoras da Indústria 4.0. Desde manutenção preditiva até controle de qualidade, o aprendizado de máquina tem transformado processos industriais, permitindo **tomadas de decisão mais inteligentes, aumento de eficiência operacional e redução de custos** (Pan & Yang, 2010; Kohavi, 1995).
#
# No setor de resíduos sólidos, **a aplicação de ML na triagem automatizada** traz múltiplos benefícios:
#
# - Redução da exposição de trabalhadores a materiais contaminados;
# - Aumento da precisão na separação de materiais por tipo, cor, formato ou condição (ex: cheios/vazios);
# - Otimização dos custos logísticos e operacionais;
# - Melhoria nos índices de reciclagem e reaproveitamento de materiais;
# - Conformidade com regulamentações ambientais e metas de ESG (Sammut & Webb, 2010; He & Garcia, 2009).
#
# ### 📦 Machine Learning para Classificação de Resíduos Recicláveis
#
# O presente projeto tem como objetivo **desenvolver e avaliar um modelo de deep learning** para a **classificação automática de resíduos recicláveis** a partir de imagens reais coletadas em uma **usina de triagem industrial**.
#
# Para isso, foi utilizado o dataset **WaRP-C (Waste Recycling Plant - Classification subset)**, que reúne **8.823 imagens reais** divididas em **6 classes principais** (como garrafas plásticas, embalagens de detergente e latas) e **28 subclasses**. A base reflete um cenário industrial com variação real de iluminação, fundo, ângulos e formatos, o que a torna um excelente campo de validação para soluções robustas em ambientes reais (Shorten & Khoshgoftaar, 2019).
#
# ---
#
# ## 🎯 Objetivos do Projeto
#
# - Criar um modelo de classificação de imagens utilizando a arquitetura ResNet50 com Transfer Learning, garantindo alta capacidade de generalização (He et al., 2016; Pan & Yang, 2010);
# - Corrigir o desbalanceamento das classes por meio de undersampling seletivo e Data Augmentation (He & Garcia, 2009);
# - Avaliar o desempenho do modelo com rigor utilizando validação cruzada (K-Fold) e métricas apropriadas para cenários desbalanceados (Kohavi, 1995; Sokolova & Lapalme, 2009);
# - Estabelecer um pipeline reprodutível que possa ser integrado em sistemas industriais de triagem.
#
# ---
#
# ## ✅ Benefícios Esperados
#
# - **Eficiência:** Automatizar a classificação de resíduos reduz o tempo e custo por tonelada triada;
# - **Segurança:** Minimiza a exposição de trabalhadores a resíduos potencialmente contaminantes;
# - **Sustentabilidade:** Aumenta a taxa de reaproveitamento de materiais, reduzindo impactos ambientais;
# - **Escalabilidade:** A solução pode ser implementada em diferentes plantas com treinamento adicional;
# - **Inovação aplicada:** Demonstra como Inteligência Artificial aplicada à sustentabilidade pode gerar impacto positivo direto na economia circular (Fawcett, 2006; Sammut & Webb, 2010).
#
# ---
#
# ## 📊 Sobre o Dataset
#
# ### 📄 Descrição
#
# O conjunto de dados **WaRP (Waste Recycling Plant)** é composto por **8.823 imagens reais** de resíduos recicláveis coletadas em uma usina de triagem industrial. Este projeto utiliza exclusivamente o subconjunto **WaRP-C**, voltado à **classificação de imagens**.
#
# As imagens estão agrupadas em **6 classes principais**, compostas por **28 subclasses**:
#
# - ♻️ **Plastic bottles**: 17 subclasses (prefixo `bottle-`) — 6.070 imagens
# - 🧪 **Glass bottles**: 3 subclasses (prefixo `glass-`) — 448 imagens
# - 📦 **Cardboards**: 2 subclasses — 650 imagens
# - 🧼 **Detergents**: 4 subclasses — 943 imagens
# - 🛢 **Canisters**: 1 categoria — 149 imagens
# - 🥫 **Cans**: 1 categoria — 562 imagens
#
# 💡 O sufixo `-full` indica que a embalagem está cheia de ar.
#
# ---
#
# ## 🧠 Estratégia de Treinamento Utilizada
#
# ### ✅ Modelo Proposto: **ResNet50 pré-treinada no ImageNet**
#
# A arquitetura **ResNet50** (He et al., 2016) foi escolhida por seu alto desempenho em tarefas de **visão computacional profunda**, especialmente quando combinada com **Transfer Learning**, técnica que permite utilizar o conhecimento aprendido em grandes datasets (como o ImageNet) e aplicá-lo em problemas específicos (Pan & Yang, 2010).
#
# **ResNet50** é uma arquitetura de redes neurais profundas introduzida por **He et al. (2016)** no artigo *"Deep Residual Learning for Image Recognition"*. Sua principal inovação é o uso de **conexões residuais** (atalhos ou skip connections) que permitem treinar redes muito profundas (com dezenas ou centenas de camadas) sem sofrer com o problema de degradação da acurácia.
#
# **📌 Principais características:**
# - 50 camadas profundas;
# - Aprendizagem residual (f(x) + x);
# - Ampla adoção como backbone em aplicações com Transfer Learning;
# - Excelente equilíbrio entre profundidade, desempenho e custo computacional.
#
# ---
#
# ## 🧪 Pipeline Detalhado
#
# ### 🔹 1. Pré-processamento
#
# - Leitura estruturada dos caminhos e rótulos das imagens, com extração da classe a partir dos diretórios.
# - Visualização da distribuição de classes para análise do desbalanceamento.
# - **Undersampling seletivo** da classe majoritária `plastic bottles`, reduzindo de **6.070 para 1.070 imagens** (aproximadamente 1/6), enquanto todas as demais classes foram mantidas intactas.
#
# 📉 **Essa decisão foi tomada com base nos seguintes fatores:**
# - A classe `plastic bottles` representava mais de **68%** do total de amostras, o que poderia **enviesar fortemente o modelo** em favor dessa classe, prejudicando o desempenho nas classes minoritárias;
# - A redução para 1.070 imagens **preserva variação suficiente** dentro da classe majoritária para evitar perda de representatividade;
# - O uso de **Data Augmentation**, **Transfer Learning (ResNet50)** e **Validação Cruzada** ajuda a **compensar a diminuição do volume de dados**, favorecendo a generalização;
# - Esta técnica segue as melhores práticas para lidar com dados desbalanceados, conforme discutido por **He & Garcia (2009)**.
# - Essa abordagem evita que o modelo se torne enviesado para a classe majoritária, melhorando a equidade na classificação (**He & Garcia, 2009**).
#
# ### 🔹 2. Aumentação de Dados (Data Augmentation)
#
# A técnica de **Data Augmentation** é usada para **aumentar artificialmente a diversidade dos dados de treino**, o que melhora a capacidade de generalização do modelo (Shorten & Khoshgoftaar, 2019).
#
# ⚙️ **Configurações utilizadas:**
#
# | Parâmetro | Justificativa |
# |-----------|---------------|
# | `rescale=1./255` | Normaliza os pixels (0 a 1), o que ajuda na convergência durante o treinamento. |
# | `rotation_range=30` | Permite rotação aleatória de até 30°, simulando ângulos de captura variados. |
# | `width_shift_range=0.3` | Translada a imagem horizontalmente em até 30% da largura. |
# | `height_shift_range=0.3` | 	Translada verticalmente até 30% da altura, útil para simular deslocamentos reais. |
# | `shear_range=0.3` | Inclinação das imagens, útil para lidar com distorções de perspectiva. |
# | `zoom_range=0.3` | Amplia ou reduz em até 30%, simulando distâncias de captura. |
# | `horizontal_flip=True` | 	Espelha horizontalmente — comum em imagens simétricas. |
# | `vertical_flip=True` | Espelha verticalmente — útil para objetos capturados de diferentes ângulos. |
# | `brightness_range=[0.7, 1.3]` | Altera o brilho da imagem, imitando diferentes condições de iluminação. |
# | `channel_shift_range=30.0` | Modifica os canais de cor, ajudando a lidar com variações em iluminação e câmeras. |
# | `fill_mode='nearest` | Preenche áreas criadas pelas transformações com os pixels vizinhos mais próximos. |
#
# ### 🔹 3. Arquitetura do Modelo
#
# ✅ **Backbone:**
# ```plaintext
# ResNet50(include_top=False, weights='imagenet')
# ```
# - Carrega uma **rede convolucional pré-treinada** no ImageNet (Transfer Learning);
# - `include_top=False` remove as camadas de classificação originais para adicionar novas adaptadas ao problema.
#
#
# ✅ **Camadas adicionadas:**
# | Camada | Objetivo |
# |-----------|---------------|
# | `GlobalAveragePooling2D()` | Reduz a dimensionalidade após convoluções, preservando os recursos mais importantes. |
# | `Dropout(0.5)` | Desativa aleatoriamente 50% dos neurônios, reduzindo o overfitting. |
# | `Dense(128, activation='relu')` | Camada totalmente conectada para aprendizado de representações complexas. |
# | `BatchNormalization()` | 	Normaliza os valores da camada anterior, acelerando o treinamento e melhorando a estabilidade. |
# | `Dropout(0.5)` | Segunda camada de regularização. |
# | `Dense(6, activation='softmax')` | Camada de saída com 6 neurônios (uma para cada classe) e softmax para classificação multiclasse. |
#
#
# > ℹ️ A arquitetura foi projetada para reduzir overfitting e melhorar a generalização, respeitando o equilíbrio entre capacidade e regularização.
#
#
# ### 🔹 4. Treinamento com Validação Cruzada K-Fold
#
# O uso de **K-Fold Cross-Validation** (Kohavi, 1995) visa garantir uma **avaliação mais robusta** e confiável, particionando os dados em **5 folds**:
# | Componente | Justificativa |
# |-----------|---------------|
# | `KFold(n_splits=5` | Permite que o modelo seja treinado e validado em diferentes subconjuntos dos dados. |
# | `shuffle=True` | Embaralha os dados para garantir que os folds sejam aleatórios e bem distribuídos. |
# | `random_state=42` | Garante reprodutibilidade. |
# | `EarlyStopping(patience=5)` | Evita overfitting interrompendo o treinamento quando não há melhora por 5 épocas consecutivas. |
# | `class_weight=compute_class_weight(...)` | Compensa o desbalanceamento atribuindo maior peso a classes minoritárias. |
# | `optimizer=Adam(learning_rate=1e-5)` | 	Otimizador estável e adaptativo (Kingma & Ba, 2015). |
#
# ---
#
# ## 📈 Avaliação
#
# Durante o treinamento de cada fold do K-Fold Cross Validation, foram calculadas as seguintes métricas para garantir uma avaliação robusta e completa do modelo:
#
# | Métrica          | O que é           | Por que é usada                               |
# |--------------------|---------------------------------------------------------------|------------------------------------------------|
# | `Accuracy`           | Proporção total de classificações corretas em relação ao total de amostras.                                                    | É uma métrica simples e intuitiva para medir desempenho geral. No entanto, pode ser enganosa em datasets desbalanceados, por isso foi complementada com outras métricas. [Sammut & Webb, 2010]            |
# | `Precision (macro)`  | Média da precisão por classe, ignorando a proporção de amostras de cada classe. Precision = TP / (TP + FP).                                                     | Avalia o quão precisas são as previsões positivas para cada classe. A versão macro garante tratamento igualitário entre classes, essencial em cenários desbalanceados. [Sokolova & Lapalme, 2009]                          |
# | `Recall (macro)`     | Média da sensibilidade (ou taxa de verdadeiros positivos) por classe. Recall = TP / (TP + FN).                                                    | Mede a capacidade do modelo de encontrar todos os exemplos positivos de cada classe. Importante para avaliar se o modelo não está ignorando classes minoritárias.              |
# | `F1-Score (macro)`   | Média harmônica entre Precision e Recall, calculada para cada classe e depois promediada (macro).                                                     | Fornece um equilíbrio entre precisão e cobertura, sendo útil especialmente em conjuntos de dados desequilibrados, onde se quer evitar tanto falsos positivos quanto falsos negativos.                  |
# | `AUC-ROC (macro)`    | Área sob a curva ROC, que mede a separabilidade entre classes. No modo macro, é a média entre as curvas de cada classe.                                                  | Indica a capacidade do modelo em distinguir entre as classes. Quanto maior o AUC, melhor a distinção. É especialmente útil em classificação multiclasse e desbalanceada. [Fawcett, 2006]        |
# | `Cohen's Kappa`      | Métrica de concordância que corrige a acurácia esperada ao acaso. Valor entre -1 e 1, sendo 1 concordância perfeita.           | Útil para avaliar a qualidade da classificação mesmo em dados desbalanceados, onde a acurácia sozinha pode ser enganosa. [Cohen, 1960]|
# | `Matriz de Confusão`      | Tabela que exibe o número de acertos e erros por classe (TP, FP, FN, TN).          | Permite análise visual e detalhada dos erros do modelo, ajudando a entender quais classes estão sendo confundidas. Essencial para diagnósticos e ajustes.|
#
#
# ### 📐 Valores Esperados por Métrica
#
# | Métrica            | Intervalo Esperado (Modelos ConvNets em Visão Computacional) | Fonte/Referência                               |
# |--------------------|---------------------------------------------------------------|------------------------------------------------|
# | Accuracy           | 85% – 95%                                                     | He et al. (2016); Pan & Yang (2010)            |
# | Precision (macro)  | 80% – 95%                                                     | Sammut & Webb (2010)                           |
# | Recall (macro)     | 80% – 95%                                                     | Kohavi (1995); He & Garcia (2009)              |
# | F1-Score (macro)   | 80% – 95%                                                     | Shorten & Khoshgoftaar (2019)                  |
# | AUC-ROC (macro)    | 0.90 – 0.98                                                   | Sammut & Webb (2010); Pan & Yang (2010)        |
# | Cohen's Kappa      | ≥ 0.80 (interpretação: "concordância substancial")            | Landis & Koch (1977), apud Sammut & Webb (2010)|
#
#
# > ℹ️ Esses valores são estimativas típicas para tarefas de classificação multiclasse bem definidas com redes convolucionais profundas. A ResNet50, em especial, costuma atingir esses patamares em bases de tamanho moderado com Transfer Learning.
#
# ---
#
# ## ⚙️ Ambiente de Execução
#
# O treinamento foi realizado em ambiente com suporte a aceleração por GPU. Especificamente, foi utilizada a **GPU NVIDIA A100**, disponível no Google Colab Pro+.
#
# 🔧 **Especificações da GPU NVIDIA A100:**
# - Arquitetura: Ampere
# - Memória: 40GB ou 80GB HBM2e
# - Ideal para Deep Learning e tarefas intensivas de treinamento
# - Suporte ao mixed precision training (float16), acelerando o treinamento de redes profundas como ResNet50
#
# 📌 **Benefícios observados:**
# - Redução significativa no tempo de treinamento por fold
# - Suporte eficiente a operações de convolução e backpropagation em lotes maiores
# - Permitiu uso de Data Augmentation em tempo real sem gargalos de desempenho
#
# 💡 A escolha dessa GPU foi essencial para treinar eficientemente o modelo com validação cruzada e Data Augmentation pesada.
#
# ---
#
#
# ## 📊 Resultados Finais
#
# Com base nos gráficos de accuracy e loss, além das matrizes de confusão de cada fold, observamos os seguintes destaques:
# - **Fold 1:** *accuracy* de validação ~0.82, perda estabilizada no final (~2.6), com sinais iniciais de underfitting.
# A matriz indicou confusões moderadas entre classes, especialmente da classe maioritária (“bottle”) e classes menos frequentes como “detergent” e “glass”.
# - **Fold 2:** *accuracy* de validação ~0.95, boa convergência com perda final ~1.3; matriz mostrou alta separação entre classes (bottle 202 acertos, detergent 152, glass 106), com poucas confusões.
# - **Fold 3, 4 e 5:** desempenho excelente, com *accuracy* e *F1-score* na faixa de 0.99–1.00. As matrizes de confusão correspondentes exibiram quase zero erros de classificação para todas as classes, sugerindo excelente generalização nesses folds.
#
# 🧾 **Métricas consolidadas (média ± desvio padrão):**
# ```
# Accuracy         : 0.9442 ± 0.0715
# Precision (macro): 0.9334 ± 0.0874
# Recall (macro)   : 0.9491 ± 0.0667
# F1-Score (macro) : 0.9386 ± 0.0812
# Cohen’s Kappa    : 0.9305 ± 0.0889
# AUC-ROC (macro)  : 0.9931 ± 0.0114
# ```
#
# 🎯 **AUC-ROC por classe:**
# ```
# - bottle              : 0.9882 ± 0.0194
# - canister            : 0.9938 ± 0.0115
# - cans                : 0.9977 ± 0.0041
# - cardboard           : 0.9966 ± 0.0062
# - detergent           : 0.9853 ± 0.0218
# - glass               : 0.9971 ± 0.0055
# ```
#
# Esses resultados refletem o equilíbrio entre generalização (folds com alto desempenho) e robustez (um fold mais desafiador, o primeiro). Segundo literatura, esses valores estão em consonância com expectativas para modelos de redes convolucionais com Transfer Learning (Accuracy entre 85–95%, AUC alta etc.).
#
# ---
#
# ## 📌 Conclusão
#
# A análise consolidada mostra que o pipeline:
#
# - Aprendeu representações de alta qualidade (ResNet50 + regularização + data augmentation), mesmo com classe majoritária reduzida.
# - Foi robusto em cenários variados, com alta consistência entre folds e excelente capacidade de transferência de aprendizado (valores de AUC‑ROC por classe acima de 0.98).
# - Apresentou **nenhum** erro nos folds superiores, o que sugere forte poder discriminativo entre resíduos recicláveis nas seis classes.
#
# Este desempenho reforça que a abordagem proposta — com Transfer Learning, Data Augmentation, validação cruzada e tratamento de classes desbalanceadas — é eficaz para classificação multiclasse em contextos industriais.
#
# ---
#
# ## ✅ Melhorias Futuras
#
# - Avaliar test set completamente separado (fold final ou hold‑out).
# - Abrir as previsões erradas do fold 1 para identificar padrões de erro e possíveis ajustes (ex.: maior foco em classes confusas, mais augmentação específica).
# - Comparar desempenho com variantes da base (como aumento/deplection diferente do undersampling) para validar sensibilidade à composição dos dados.
#
# ---
#
# ## 📚 Referências Bibliográficas
#
# - Cohen, J. (1960). A coefficient of agreement for nominal scales. Educational and Psychological Measurement, 20(1), 37–46.
# - Fawcett, T. (2006). An introduction to ROC analysis. Pattern Recognition Letters, 27(8), 861–874.
# - He, H., & Garcia, E. A. (2009). Learning from imbalanced data. IEEE Transactions on Knowledge and Data Engineering, 21(9), 1263–1284.
# - He, K., Zhang, X., Ren, S., & Sun, J. (2016). Deep Residual Learning for Image Recognition. In Proceedings of the IEEE Conference on Computer Vision and Pattern Recognition (CVPR), 770–778.
# - Kingma, D. P., & Ba, J. (2015). Adam: A method for stochastic optimization. arXiv preprint arXiv:1412.6980.
# - Kohavi, R. (1995). A study of cross-validation and bootstrap for accuracy estimation and model selection. In Proceedings of the 14th International Joint Conference on Artificial Intelligence (IJCAI), 1137–1143.
# - Landis, J. R., & Koch, G. G. (1977). The measurement of observer agreement for categorical data. Biometrics, 33(1), 159–174.
# - Pan, S. J., & Yang, Q. (2010). A survey on transfer learning. IEEE Transactions on Knowledge and Data Engineering, 22(10), 1345–1359.
# - Sammut, C., & Webb, G. I. (2010). Encyclopedia of Machine Learning. Springer.
# - Shorten, C., & Khoshgoftaar, T. M. (2019). A survey on Image Data Augmentation for deep learning. Journal of Big Data, 6(1), 60.
# - Sokolova, M., & Lapalme, G. (2009). A systematic analysis of performance measures for classification tasks. Information Processing & Management, 45(4), 427–437.
#
# ---

# %% [markdown]
# ## ⚠️ **Executar esse bloco de código apenas se estiver usando Google Colab** - Conectar ao Google Drive:

# %%
# Conectar ao Google Drive - Executar apenas se estiver usando Google Colab

from google.colab import drive

print("Iniciando conexão com o Google Drive...")

drive.mount('/content/drive')

print("Google Drive conectado com sucesso!")
# Out:
# Iniciando conexão com o Google Drive...
# Mounted at /content/drive
# Google Drive conectado com sucesso!

# %% [markdown]
# ## 🧠 Instalação dos pacotes necessários

# %%
# instalar os pacotes necessarios

# !pip install tensorflow
# !pip install scikit-learn
# !pip install matplotlib
# !pip install seaborn
# !pip install tensorflow
# !pip install opencv-python
# !pip install pandas
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## 📦 Imports necessários

# %%
import os
import datetime
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import label_binarize
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.metrics import Precision, Recall
from sklearn.model_selection import KFold
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    roc_auc_score,
    cohen_kappa_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
    precision_score,
    recall_score,
    accuracy_score
)
import pandas as pd

# %% [markdown]
# ## 📁 Definição dos caminhos dos dados

# %%
# train_dir = '../data/Warp-C/train_crops' # se estiver trabalhando com pasta local no vscode
train_dir = '/content/drive/MyDrive/data/Warp-C/train_crops' # se estiver trabalhando com pasta do google drive no google colab

# test_dir = '../data/Warp-C/test_crops' # se estiver trabalhando com pasta local no vscode
test_dir = '/content/drive/MyDrive/data/Warp-C/test_crops' # se estiver trabalhando com pasta do google drive no google colab

# %% [markdown]
# ## 🔀 Criar dataframe com caminho da imagem e rótulo

# %%
# Criar dataframe com caminho da imagem e rótulo:

image_paths = []
labels = []

for class_dir in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_dir)
    for root, _, files in os.walk(class_path):
        for fname in files:
            if fname.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp')):  # apenas imagens
                image_paths.append(os.path.join(root, fname))
                labels.append(class_dir)

df = pd.DataFrame({'filename': image_paths, 'label': labels})

# %% [markdown]
# ## 🔎 Análise Exploratória dos dados

# %%
# Análise Exploratória dos dados:

# Gráfico de contagem com valores ao lado das barras (dataset completo)
plt.figure(figsize=(12, 6))
ax = sns.countplot(y=df['label'], palette='viridis')
plt.title('Distribuição das classes')
plt.xlabel('Contagem')
plt.ylabel('Classe')

# Adicionar valores ao lado de cada barra
for container in ax.containers:
    ax.bar_label(container, label_type='edge', padding=3)


# Calcular e exibir o somatório total
total = df['label'].count()
plt.text(0.95, 0.05, f'Total: {total}', transform=plt.gca().transAxes,
         fontsize=12, color='black', ha='right', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Administrador\AppData\Local\Temp\ipykernel_12936\3462239903.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(y=df['label'], palette='viridis')

# %% [markdown]
# ## 🔻 Undersampling Seletivo

# %%
# Subamostragem da classe majoritária (undersampling):

# Reduzir Plastic bottles para 2000 amostras
df_plastic = df[df['label'] == 'bottle'].sample(n=1071, random_state=42)

# Manter todas as outras classes como estão
df_others = df[df['label'] != 'bottle']


# Concatenar e embaralhar
df = pd.concat([df_plastic, df_others], axis=0).sample(frac=1, random_state=42).reset_index(drop=True)

# Novo gráfico de contagem com destaque visual
plt.figure(figsize=(12, 6))
ax = sns.countplot(y=df['label'], palette='viridis')
plt.title('Distribuição das classes após subamostragem (Undersampling)')
plt.xlabel('Contagem')
plt.ylabel('Classe')


# Adicionar rótulos com as quantidades ao lado das barras
for container in ax.containers:
    ax.bar_label(container, label_type='edge', padding=3)

# Calcular e exibir o somatório total
total = df['label'].count()
plt.text(0.95, 0.05, f'Total: {total}', transform=plt.gca().transAxes,
         fontsize=12, color='black', ha='right', va='bottom', fontweight='bold')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\Administrador\AppData\Local\Temp\ipykernel_12936\1844109535.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(y=df['label'], palette='viridis')

# %% [markdown]
# ## 🧪 Data Augmentation

# %%
# Data Augmentation:
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.7, 1.3],
    channel_shift_range=30.0,
    fill_mode='nearest'
)

validation_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# ## 🧠 Definição do modelo com ResNet50

# %%
# Definição do modelo com ResNet50:

resnet_model = Sequential([
    ResNet50(include_top=False, input_shape=(224, 224, 3), weights='imagenet'),
    GlobalAveragePooling2D(),
    Dropout(0.5),
    Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    Dropout(0.5),
    Dense(6, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(0.01))
])


resnet_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5, clipnorm=1.0),
    loss='categorical_crossentropy',
    metrics=['accuracy', Precision(name='precision'), Recall(name='recall')]
)

resnet_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,851,270 (90.99 MB)
#  Trainable params: 23,797,894 (90.78 MB)
#  Non-trainable params: 53,376 (208.50 KB)

# %% [markdown]
# ## 🚀 Treinamento com K-Fold

# %%
# Treinamento com K-Fold:

# Armazenamento das métricas por fold
val_acc_per_fold = []
val_loss_per_fold = []
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

kf = KFold(n_splits=5, shuffle=True, random_state=42)

for fold, (train_idx, val_idx) in enumerate(kf.split(df)):
    print(f"\n📁 Treinando Fold {fold + 1}...\n")

    # Split
    train_df = df.iloc[train_idx]
    val_df = df.iloc[val_idx]

    # Geradores
    train_gen = train_datagen.flow_from_dataframe(
        train_df,
        x_col='filename',
        y_col='label',
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='training',
        shuffle=True
    )

    val_gen = validation_datagen.flow_from_dataframe(
        val_df,
        x_col='filename',
        y_col='label',
        target_size=(224, 224),
        batch_size=32,
        shuffle=False
    )

    # Pesos das Classes (Class Weights)
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(train_gen.classes),
        y=train_gen.classes
    )
    class_weights_dict = dict(enumerate(class_weights))

    # Diretório de log específico por fold com timestamp
    log_dir = f"../outputs/logs/fold_{fold+1}_{datetime.datetime.now().strftime('%Y%m%d-%H%M%S')}"
    tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

    # Modelo
    history = resnet_model.fit(
        train_gen,
        epochs=60,
        # epochs=2,
        validation_data=val_gen,
        class_weight=class_weights_dict,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5),
            tensorboard_callback
        ]
    )


    # Avaliação final do fold
    results = resnet_model.evaluate(val_gen)
    val_acc_per_fold.append(results[1])
    val_loss_per_fold.append(results[0])

    # Salvamento no final de cada fold
    resnet_model.save(f'model_fold_{fold+1}.keras')
    print(f"\n💾 Modelo salvo Fold {fold+1}")


    # Visualização de métricas - Gráficos de Acurácia e Loss a cada fold
    best_epoch_acc = np.argmax(history.history['val_accuracy']) + 1
    best_epoch_loss = np.argmin(history.history['val_loss']) + 1

    fig, axs = plt.subplots(1, 2, figsize=(14, 5))
    fig.suptitle(f'Treinamento - Fold {fold + 1}', fontsize=16)

    # Accuracy
    axs[0].plot(history.history['accuracy'], 'r-', label='Training')
    axs[0].plot(history.history['val_accuracy'], 'g-', label='Validation')
    axs[0].scatter(best_epoch_acc, history.history['val_accuracy'][best_epoch_acc-1], color='blue', label=f'Best epoch (accuracy) = {best_epoch_acc}')
    axs[0].set_title("Training and Validation Accuracy")
    axs[0].set_xlabel("Epochs")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend()

    # Loss
    axs[1].plot(history.history['loss'], 'r-', label='Training')
    axs[1].plot(history.history['val_loss'], 'g-', label='Validation')
    axs[1].scatter(best_epoch_loss, history.history['val_loss'][best_epoch_loss-1], color='blue', label=f'Best epoch (loss) = {best_epoch_loss}')
    axs[1].set_title("Training and Validation Loss")
    axs[1].set_xlabel("Epochs")
    axs[1].set_ylabel("Loss")
    axs[1].legend()

    plt.tight_layout()
    plt.show()

    # Matriz de confusão
    y_true = val_gen.classes
    y_pred = resnet_model.predict(val_gen)
    y_pred_classes = np.argmax(y_pred, axis=1)

    labels = list(val_gen.class_indices.keys())
    cm = confusion_matrix(y_true, y_pred_classes)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    fig, ax = plt.subplots(figsize=(6, 6))
    disp.plot(cmap='Blues', ax=ax, values_format='d')
    plt.title("Confusion Matrix")

    acc = accuracy_score(y_true, y_pred_classes)
    prec = precision_score(y_true, y_pred_classes, average='macro')
    rec = recall_score(y_true, y_pred_classes, average='macro')
    f1 = f1_score(y_true, y_pred_classes, average='macro')

    # Salva métricas do fold
    accuracy_scores.append(acc)
    precision_scores.append(prec)
    recall_scores.append(rec)
    f1_scores.append(f1)



    # Mostra métricas
    plt.figtext(0.5, -0.1,
                f"Accuracy: {acc:.2f} | Precision: {prec:.2f} | Recall: {rec:.2f} | F1 Score: {f1:.2f}",
                ha='center', fontsize=12)
    plt.tight_layout()
    plt.show()


# Resumo final dos folds
print("\nResultados Cross-Validation:")
print(f"Accuracy : {np.mean(accuracy_scores):.4f} ± {np.std(accuracy_scores):.4f}")
print(f"Precision: {np.mean(precision_scores):.4f} ± {np.std(precision_scores):.4f}")
print(f"Recall   : {np.mean(recall_scores):.4f} ± {np.std(recall_scores):.4f}")
print(f"F1 Score : {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
# Out:
# 📁 Treinando Fold 1...
#
# Found 3082 validated image filenames belonging to 6 classes.
# Found 771 validated image filenames belonging to 6 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 3159s 32s/step - accuracy: 0.1692 - loss: 5.4536 - precision: 0.1678 - recall: 0.1070 - val_accuracy: 0.2490 - val_loss: 4.6005 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 519ms/step - accuracy: 0.2103 - loss: 5.2070 - precision: 0.2075 - recall: 0.1378 - val_accuracy: 0.2698 - val_loss: 5.0583 - val_precision: 0.2991 - val_recall: 0.2607
# Epoch 3/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.2552 - loss: 4.8845 - precision: 0.2733 - recall: 0.1872 - val_accuracy: 0.2866 - val_loss: 4.9171 - val_precision: 0.3395 - val_recall: 0.2387
# Epoch 4/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.2841 - loss: 4.6715 - precision: 0.2997 - recall: 0.2066 - val_accuracy: 0.2957 - val_loss: 4.4287 - val_precision: 0.3042 - val_recall: 0.0947
# Epoch 5/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.3175 - loss: 4.5302 - precision: 0.3583 - recall: 0.2447 - val_accuracy: 0.2335 - val_loss: 4.6973 - val_precision: 0.2394 - val_recall: 0.1543
# Epoch 6/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.3694 - loss: 4.3646 - precision: 0.4026 - recall: 0.2904 - val_accuracy: 0.2205 - val_loss: 4.9626 - val_precision: 0.2226 - val_recall: 0.1686
# Epoch 7/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.4164 - loss: 4.1445 - precision: 0.4540 - recall: 0.3410 - val_accuracy: 0.3281 - val_loss: 4.6896 - val_precision: 0.3422 - val_recall: 0.2490
# Epoch 8/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.4227 - loss: 4.1646 - precision: 0.4751 - recall: 0.3604 - val_accuracy: 0.4306 - val_loss: 4.3211 - val_precision: 0.4594 - val_recall: 0.3450
# Epoch 9/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 512ms/step - accuracy: 0.4837 - loss: 3.9229 - precision: 0.5467 - recall: 0.4336 - val_accuracy: 0.5435 - val_loss: 3.9049 - val_precision: 0.5942 - val_recall: 0.4786
# Epoch 10/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 515ms/step - accuracy: 0.5247 - loss: 3.9417 - precision: 0.5741 - recall: 0.4547 - val_accuracy: 0.6589 - val_loss: 3.5910 - val_precision: 0.7074 - val_recall: 0.5863
# Epoch 11/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.5305 - loss: 3.8147 - precision: 0.5785 - recall: 0.4651 - val_accuracy: 0.6991 - val_loss: 3.4758 - val_precision: 0.7337 - val_recall: 0.6291
# Epoch 12/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.5555 - loss: 3.7663 - precision: 0.6060 - recall: 0.4888 - val_accuracy: 0.7082 - val_loss: 3.4609 - val_precision: 0.7350 - val_recall: 0.6654
# Epoch 13/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.5824 - loss: 3.6092 - precision: 0.6376 - recall: 0.5103 - val_accuracy: 0.7004 - val_loss: 3.4530 - val_precision: 0.7321 - val_recall: 0.6628
# Epoch 14/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 499ms/step - accuracy: 0.5930 - loss: 3.6030 - precision: 0.6515 - recall: 0.5328 - val_accuracy: 0.6965 - val_loss: 3.4965 - val_precision: 0.7342 - val_recall: 0.6628
# Epoch 15/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 48s 497ms/step - accuracy: 0.6122 - loss: 3.5530 - precision: 0.6764 - recall: 0.5557 - val_accuracy: 0.7056 - val_loss: 3.4807 - val_precision: 0.7383 - val_recall: 0.6770
# Epoch 16/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.6273 - loss: 3.4648 - precision: 0.6894 - recall: 0.5720 - val_accuracy: 0.7237 - val_loss: 3.3923 - val_precision: 0.7550 - val_recall: 0.6874
# Epoch 17/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.6269 - loss: 3.4557 - precision: 0.6835 - recall: 0.5811 - val_accuracy: 0.7315 - val_loss: 3.4072 - val_precision: 0.7581 - val_recall: 0.6952
# Epoch 18/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 502ms/step - accuracy: 0.6421 - loss: 3.3853 - precision: 0.6959 - recall: 0.5863 - val_accuracy: 0.7289 - val_loss: 3.3796 - val_precision: 0.7666 - val_recall: 0.7030
# Epoch 19/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 513ms/step - accuracy: 0.6406 - loss: 3.4271 - precision: 0.6929 - recall: 0.5891 - val_accuracy: 0.7562 - val_loss: 3.2623 - val_precision: 0.7997 - val_recall: 0.7250
# Epoch 20/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 513ms/step - accuracy: 0.6767 - loss: 3.3593 - precision: 0.7418 - recall: 0.6191 - val_accuracy: 0.7575 - val_loss: 3.3082 - val_precision: 0.8032 - val_recall: 0.7198
# Epoch 21/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.6720 - loss: 3.3195 - precision: 0.7211 - recall: 0.6219 - val_accuracy: 0.7549 - val_loss: 3.2637 - val_precision: 0.7945 - val_recall: 0.7173
# Epoch 22/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 513ms/step - accuracy: 0.7042 - loss: 3.2664 - precision: 0.7613 - recall: 0.6514 - val_accuracy: 0.7497 - val_loss: 3.2573 - val_precision: 0.7951 - val_recall: 0.7198
# Epoch 23/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.6961 - loss: 3.2211 - precision: 0.7607 - recall: 0.6434 - val_accuracy: 0.7613 - val_loss: 3.2250 - val_precision: 0.8110 - val_recall: 0.7289
# Epoch 24/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.7168 - loss: 3.1501 - precision: 0.7760 - recall: 0.6639 - val_accuracy: 0.7821 - val_loss: 3.1478 - val_precision: 0.8250 - val_recall: 0.7523
# Epoch 25/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.7153 - loss: 3.1917 - precision: 0.7715 - recall: 0.6592 - val_accuracy: 0.7730 - val_loss: 3.1464 - val_precision: 0.8171 - val_recall: 0.7419
# Epoch 26/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 501ms/step - accuracy: 0.7345 - loss: 3.1145 - precision: 0.7794 - recall: 0.6854 - val_accuracy: 0.7756 - val_loss: 3.1460 - val_precision: 0.8174 - val_recall: 0.7432
# Epoch 27/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.7478 - loss: 3.0836 - precision: 0.7963 - recall: 0.7014 - val_accuracy: 0.7821 - val_loss: 3.0957 - val_precision: 0.8198 - val_recall: 0.7613
# Epoch 28/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 512ms/step - accuracy: 0.7398 - loss: 3.0421 - precision: 0.7946 - recall: 0.7006 - val_accuracy: 0.7821 - val_loss: 3.0885 - val_precision: 0.8242 - val_recall: 0.7601
# Epoch 29/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.7559 - loss: 3.0124 - precision: 0.8082 - recall: 0.7019 - val_accuracy: 0.7834 - val_loss: 3.0600 - val_precision: 0.8251 - val_recall: 0.7588
# Epoch 30/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 503ms/step - accuracy: 0.7531 - loss: 3.0031 - precision: 0.8074 - recall: 0.7109 - val_accuracy: 0.7886 - val_loss: 3.0353 - val_precision: 0.8319 - val_recall: 0.7639
# Epoch 31/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.7582 - loss: 2.9833 - precision: 0.8067 - recall: 0.7098 - val_accuracy: 0.7886 - val_loss: 3.0465 - val_precision: 0.8260 - val_recall: 0.7575
# Epoch 32/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.7690 - loss: 2.9367 - precision: 0.8136 - recall: 0.7256 - val_accuracy: 0.7860 - val_loss: 3.0458 - val_precision: 0.8184 - val_recall: 0.7601
# Epoch 33/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 513ms/step - accuracy: 0.7893 - loss: 2.8553 - precision: 0.8295 - recall: 0.7511 - val_accuracy: 0.7951 - val_loss: 3.0321 - val_precision: 0.8224 - val_recall: 0.7626
# Epoch 34/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 517ms/step - accuracy: 0.7814 - loss: 2.8615 - precision: 0.8247 - recall: 0.7412 - val_accuracy: 0.7964 - val_loss: 2.9819 - val_precision: 0.8324 - val_recall: 0.7730
# Epoch 35/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 515ms/step - accuracy: 0.7913 - loss: 2.8040 - precision: 0.8381 - recall: 0.7469 - val_accuracy: 0.8042 - val_loss: 2.9581 - val_precision: 0.8301 - val_recall: 0.7795
# Epoch 36/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 506ms/step - accuracy: 0.7801 - loss: 2.7759 - precision: 0.8247 - recall: 0.7454 - val_accuracy: 0.8132 - val_loss: 2.9275 - val_precision: 0.8412 - val_recall: 0.7899
# Epoch 37/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 504ms/step - accuracy: 0.7842 - loss: 2.8258 - precision: 0.8209 - recall: 0.7380 - val_accuracy: 0.8119 - val_loss: 2.9055 - val_precision: 0.8349 - val_recall: 0.7873
# Epoch 38/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 504ms/step - accuracy: 0.8092 - loss: 2.7002 - precision: 0.8544 - recall: 0.7752 - val_accuracy: 0.8067 - val_loss: 2.9012 - val_precision: 0.8372 - val_recall: 0.7873
# Epoch 39/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.8130 - loss: 2.7215 - precision: 0.8566 - recall: 0.7841 - val_accuracy: 0.8210 - val_loss: 2.8862 - val_precision: 0.8390 - val_recall: 0.7977
# Epoch 40/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.7980 - loss: 2.7386 - precision: 0.8449 - recall: 0.7674 - val_accuracy: 0.8132 - val_loss: 2.8780 - val_precision: 0.8374 - val_recall: 0.7951
# Epoch 41/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 513ms/step - accuracy: 0.8117 - loss: 2.6768 - precision: 0.8494 - recall: 0.7732 - val_accuracy: 0.8106 - val_loss: 2.8475 - val_precision: 0.8395 - val_recall: 0.7938
# Epoch 42/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.8018 - loss: 2.7066 - precision: 0.8425 - recall: 0.7759 - val_accuracy: 0.7990 - val_loss: 2.8933 - val_precision: 0.8273 - val_recall: 0.7769
# Epoch 43/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 510ms/step - accuracy: 0.8097 - loss: 2.6051 - precision: 0.8523 - recall: 0.7793 - val_accuracy: 0.8054 - val_loss: 2.8457 - val_precision: 0.8281 - val_recall: 0.7873
# Epoch 44/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 514ms/step - accuracy: 0.8157 - loss: 2.6124 - precision: 0.8509 - recall: 0.7796 - val_accuracy: 0.7951 - val_loss: 2.8854 - val_precision: 0.8281 - val_recall: 0.7808
# Epoch 45/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.8340 - loss: 2.5687 - precision: 0.8715 - recall: 0.8040 - val_accuracy: 0.7977 - val_loss: 2.8963 - val_precision: 0.8276 - val_recall: 0.7847
# Epoch 46/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.8356 - loss: 2.5631 - precision: 0.8639 - recall: 0.8048 - val_accuracy: 0.8119 - val_loss: 2.8202 - val_precision: 0.8372 - val_recall: 0.7938
# Epoch 47/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 512ms/step - accuracy: 0.8214 - loss: 2.5209 - precision: 0.8583 - recall: 0.7971 - val_accuracy: 0.8132 - val_loss: 2.8101 - val_precision: 0.8322 - val_recall: 0.7977
# Epoch 48/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 502ms/step - accuracy: 0.8395 - loss: 2.4899 - precision: 0.8648 - recall: 0.8118 - val_accuracy: 0.8145 - val_loss: 2.7818 - val_precision: 0.8322 - val_recall: 0.7977
# Epoch 49/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 503ms/step - accuracy: 0.8369 - loss: 2.5207 - precision: 0.8644 - recall: 0.8046 - val_accuracy: 0.8145 - val_loss: 2.7777 - val_precision: 0.8331 - val_recall: 0.8029
# Epoch 50/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.8461 - loss: 2.5048 - precision: 0.8757 - recall: 0.8147 - val_accuracy: 0.8119 - val_loss: 2.7458 - val_precision: 0.8333 - val_recall: 0.7977
# Epoch 51/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.8661 - loss: 2.3822 - precision: 0.8927 - recall: 0.8390 - val_accuracy: 0.8145 - val_loss: 2.7384 - val_precision: 0.8297 - val_recall: 0.7964
# Epoch 52/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.8468 - loss: 2.4106 - precision: 0.8793 - recall: 0.8195 - val_accuracy: 0.8171 - val_loss: 2.7048 - val_precision: 0.8365 - val_recall: 0.8029
# Epoch 53/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 506ms/step - accuracy: 0.8515 - loss: 2.4165 - precision: 0.8800 - recall: 0.8266 - val_accuracy: 0.8184 - val_loss: 2.6702 - val_precision: 0.8453 - val_recall: 0.8080
# Epoch 54/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 512ms/step - accuracy: 0.8746 - loss: 2.3359 - precision: 0.9060 - recall: 0.8473 - val_accuracy: 0.8184 - val_loss: 2.6503 - val_precision: 0.8392 - val_recall: 0.7990
# Epoch 55/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.8558 - loss: 2.3560 - precision: 0.8857 - recall: 0.8323 - val_accuracy: 0.8288 - val_loss: 2.6361 - val_precision: 0.8458 - val_recall: 0.8184
# Epoch 56/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 513ms/step - accuracy: 0.8690 - loss: 2.3102 - precision: 0.8877 - recall: 0.8419 - val_accuracy: 0.8262 - val_loss: 2.6433 - val_precision: 0.8400 - val_recall: 0.8171
# Epoch 57/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 504ms/step - accuracy: 0.8633 - loss: 2.3220 - precision: 0.8977 - recall: 0.8405 - val_accuracy: 0.8223 - val_loss: 2.6192 - val_precision: 0.8347 - val_recall: 0.8119
# Epoch 58/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.8704 - loss: 2.2832 - precision: 0.8915 - recall: 0.8515 - val_accuracy: 0.8327 - val_loss: 2.6009 - val_precision: 0.8480 - val_recall: 0.8249
# Epoch 59/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.8649 - loss: 2.2615 - precision: 0.8838 - recall: 0.8400 - val_accuracy: 0.8275 - val_loss: 2.5698 - val_precision: 0.8389 - val_recall: 0.8171
# Epoch 60/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 51s 520ms/step - accuracy: 0.8794 - loss: 2.2240 - precision: 0.9032 - recall: 0.8628 - val_accuracy: 0.8093 - val_loss: 2.6290 - val_precision: 0.8231 - val_recall: 0.8029
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.8016 - loss: 2.6973 - precision: 0.8154 - recall: 0.7914
#
# 💾 Modelo salvo Fold 1
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 253ms/step
# 📁 Treinando Fold 2...
#
# Found 3082 validated image filenames belonging to 6 classes.
# Found 771 validated image filenames belonging to 6 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 518ms/step - accuracy: 0.8584 - loss: 2.3336 - precision: 0.8804 - recall: 0.8329 - val_accuracy: 0.9728 - val_loss: 1.9851 - val_precision: 0.9775 - val_recall: 0.9598
# Epoch 2/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 514ms/step - accuracy: 0.8533 - loss: 2.2826 - precision: 0.8781 - recall: 0.8326 - val_accuracy: 0.9650 - val_loss: 1.9853 - val_precision: 0.9697 - val_recall: 0.9559
# Epoch 3/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.8521 - loss: 2.3139 - precision: 0.8778 - recall: 0.8267 - val_accuracy: 0.9507 - val_loss: 1.9737 - val_precision: 0.9593 - val_recall: 0.9468
# Epoch 4/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.8567 - loss: 2.2595 - precision: 0.8811 - recall: 0.8350 - val_accuracy: 0.9455 - val_loss: 1.9793 - val_precision: 0.9528 - val_recall: 0.9429
# Epoch 5/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.8534 - loss: 2.2359 - precision: 0.8780 - recall: 0.8317 - val_accuracy: 0.9533 - val_loss: 1.9510 - val_precision: 0.9619 - val_recall: 0.9494
# Epoch 6/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.8701 - loss: 2.1637 - precision: 0.8853 - recall: 0.8526 - val_accuracy: 0.9585 - val_loss: 1.9551 - val_precision: 0.9656 - val_recall: 0.9468
# Epoch 7/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.8635 - loss: 2.1568 - precision: 0.8838 - recall: 0.8412 - val_accuracy: 0.9520 - val_loss: 1.9292 - val_precision: 0.9619 - val_recall: 0.9507
# Epoch 8/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.8677 - loss: 2.1342 - precision: 0.8894 - recall: 0.8509 - val_accuracy: 0.9390 - val_loss: 1.9520 - val_precision: 0.9496 - val_recall: 0.9287
# Epoch 9/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.8685 - loss: 2.1296 - precision: 0.8911 - recall: 0.8465 - val_accuracy: 0.9468 - val_loss: 1.9161 - val_precision: 0.9528 - val_recall: 0.9429
# Epoch 10/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 501ms/step - accuracy: 0.8831 - loss: 2.0774 - precision: 0.9024 - recall: 0.8638 - val_accuracy: 0.9533 - val_loss: 1.8822 - val_precision: 0.9606 - val_recall: 0.9494
# Epoch 11/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 504ms/step - accuracy: 0.8838 - loss: 2.0685 - precision: 0.9011 - recall: 0.8586 - val_accuracy: 0.9559 - val_loss: 1.8718 - val_precision: 0.9644 - val_recall: 0.9494
# Epoch 12/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.8991 - loss: 1.9944 - precision: 0.9160 - recall: 0.8852 - val_accuracy: 0.9468 - val_loss: 1.8645 - val_precision: 0.9590 - val_recall: 0.9416
# Epoch 13/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.8883 - loss: 2.0336 - precision: 0.9060 - recall: 0.8719 - val_accuracy: 0.9468 - val_loss: 1.8626 - val_precision: 0.9515 - val_recall: 0.9416
# Epoch 14/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 503ms/step - accuracy: 0.8859 - loss: 2.0163 - precision: 0.9030 - recall: 0.8662 - val_accuracy: 0.9442 - val_loss: 1.8574 - val_precision: 0.9488 - val_recall: 0.9364
# Epoch 15/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.8840 - loss: 1.9974 - precision: 0.9045 - recall: 0.8690 - val_accuracy: 0.9468 - val_loss: 1.8435 - val_precision: 0.9516 - val_recall: 0.9429
# Epoch 16/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 513ms/step - accuracy: 0.9009 - loss: 1.9363 - precision: 0.9220 - recall: 0.8841 - val_accuracy: 0.9455 - val_loss: 1.8331 - val_precision: 0.9516 - val_recall: 0.9429
# Epoch 17/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 512ms/step - accuracy: 0.8869 - loss: 1.9549 - precision: 0.9057 - recall: 0.8633 - val_accuracy: 0.9429 - val_loss: 1.8335 - val_precision: 0.9476 - val_recall: 0.9390
# Epoch 18/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.9078 - loss: 1.8940 - precision: 0.9203 - recall: 0.8928 - val_accuracy: 0.9416 - val_loss: 1.8213 - val_precision: 0.9463 - val_recall: 0.9377
# Epoch 19/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.8968 - loss: 1.8846 - precision: 0.9174 - recall: 0.8857 - val_accuracy: 0.9481 - val_loss: 1.7997 - val_precision: 0.9515 - val_recall: 0.9416
# Epoch 20/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.9052 - loss: 1.8716 - precision: 0.9256 - recall: 0.8912 - val_accuracy: 0.9429 - val_loss: 1.7806 - val_precision: 0.9465 - val_recall: 0.9416
# Epoch 21/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.8983 - loss: 1.8589 - precision: 0.9130 - recall: 0.8794 - val_accuracy: 0.9468 - val_loss: 1.7779 - val_precision: 0.9505 - val_recall: 0.9455
# Epoch 22/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 502ms/step - accuracy: 0.9018 - loss: 1.8320 - precision: 0.9219 - recall: 0.8909 - val_accuracy: 0.9481 - val_loss: 1.7632 - val_precision: 0.9529 - val_recall: 0.9455
# Epoch 23/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.9161 - loss: 1.8447 - precision: 0.9285 - recall: 0.9026 - val_accuracy: 0.9377 - val_loss: 1.7588 - val_precision: 0.9426 - val_recall: 0.9377
# Epoch 24/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 510ms/step - accuracy: 0.9154 - loss: 1.7703 - precision: 0.9296 - recall: 0.9061 - val_accuracy: 0.9339 - val_loss: 1.7774 - val_precision: 0.9375 - val_recall: 0.9339
# Epoch 25/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.9189 - loss: 1.7668 - precision: 0.9315 - recall: 0.9069 - val_accuracy: 0.9403 - val_loss: 1.7216 - val_precision: 0.9436 - val_recall: 0.9339
# Epoch 26/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 506ms/step - accuracy: 0.9159 - loss: 1.7303 - precision: 0.9313 - recall: 0.9070 - val_accuracy: 0.9377 - val_loss: 1.7248 - val_precision: 0.9413 - val_recall: 0.9364
# Epoch 27/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 502ms/step - accuracy: 0.9239 - loss: 1.7155 - precision: 0.9350 - recall: 0.9150 - val_accuracy: 0.9455 - val_loss: 1.6820 - val_precision: 0.9505 - val_recall: 0.9455
# Epoch 28/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 514ms/step - accuracy: 0.9235 - loss: 1.6810 - precision: 0.9381 - recall: 0.9156 - val_accuracy: 0.9351 - val_loss: 1.6813 - val_precision: 0.9385 - val_recall: 0.9300
# Epoch 29/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 52s 531ms/step - accuracy: 0.9134 - loss: 1.7129 - precision: 0.9237 - recall: 0.9006 - val_accuracy: 0.9494 - val_loss: 1.6797 - val_precision: 0.9530 - val_recall: 0.9468
# Epoch 30/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9293 - loss: 1.6564 - precision: 0.9411 - recall: 0.9191 - val_accuracy: 0.9403 - val_loss: 1.6469 - val_precision: 0.9415 - val_recall: 0.9390
# Epoch 31/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.9324 - loss: 1.6555 - precision: 0.9438 - recall: 0.9225 - val_accuracy: 0.9455 - val_loss: 1.6129 - val_precision: 0.9490 - val_recall: 0.9416
# Epoch 32/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 512ms/step - accuracy: 0.9263 - loss: 1.6222 - precision: 0.9397 - recall: 0.9163 - val_accuracy: 0.9455 - val_loss: 1.6070 - val_precision: 0.9528 - val_recall: 0.9416
# Epoch 33/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 503ms/step - accuracy: 0.9320 - loss: 1.6105 - precision: 0.9394 - recall: 0.9213 - val_accuracy: 0.9468 - val_loss: 1.6045 - val_precision: 0.9503 - val_recall: 0.9429
# Epoch 34/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.9293 - loss: 1.5750 - precision: 0.9404 - recall: 0.9194 - val_accuracy: 0.9313 - val_loss: 1.6165 - val_precision: 0.9361 - val_recall: 0.9313
# Epoch 35/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 504ms/step - accuracy: 0.9293 - loss: 1.5662 - precision: 0.9379 - recall: 0.9218 - val_accuracy: 0.9507 - val_loss: 1.5670 - val_precision: 0.9505 - val_recall: 0.9468
# Epoch 36/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 518ms/step - accuracy: 0.9321 - loss: 1.5449 - precision: 0.9434 - recall: 0.9245 - val_accuracy: 0.9390 - val_loss: 1.6076 - val_precision: 0.9412 - val_recall: 0.9339
# Epoch 37/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 512ms/step - accuracy: 0.9292 - loss: 1.5415 - precision: 0.9361 - recall: 0.9200 - val_accuracy: 0.9416 - val_loss: 1.5551 - val_precision: 0.9450 - val_recall: 0.9364
# Epoch 38/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.9453 - loss: 1.4820 - precision: 0.9557 - recall: 0.9407 - val_accuracy: 0.9313 - val_loss: 1.5419 - val_precision: 0.9360 - val_recall: 0.9300
# Epoch 39/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.9424 - loss: 1.4852 - precision: 0.9490 - recall: 0.9330 - val_accuracy: 0.9339 - val_loss: 1.5538 - val_precision: 0.9371 - val_recall: 0.9274
# Epoch 40/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 511ms/step - accuracy: 0.9341 - loss: 1.5026 - precision: 0.9411 - recall: 0.9266 - val_accuracy: 0.9235 - val_loss: 1.5225 - val_precision: 0.9270 - val_recall: 0.9222
# Epoch 41/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9369 - loss: 1.4670 - precision: 0.9488 - recall: 0.9284 - val_accuracy: 0.9274 - val_loss: 1.5042 - val_precision: 0.9344 - val_recall: 0.9235
# Epoch 42/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9540 - loss: 1.4056 - precision: 0.9601 - recall: 0.9475 - val_accuracy: 0.9403 - val_loss: 1.4902 - val_precision: 0.9426 - val_recall: 0.9377
# Epoch 43/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.9568 - loss: 1.4068 - precision: 0.9613 - recall: 0.9511 - val_accuracy: 0.9377 - val_loss: 1.4881 - val_precision: 0.9424 - val_recall: 0.9339
# Epoch 44/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 503ms/step - accuracy: 0.9439 - loss: 1.4197 - precision: 0.9502 - recall: 0.9366 - val_accuracy: 0.9377 - val_loss: 1.4776 - val_precision: 0.9423 - val_recall: 0.9326
# Epoch 45/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 503ms/step - accuracy: 0.9465 - loss: 1.3798 - precision: 0.9523 - recall: 0.9407 - val_accuracy: 0.9377 - val_loss: 1.4630 - val_precision: 0.9398 - val_recall: 0.9313
# Epoch 46/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.9459 - loss: 1.3822 - precision: 0.9502 - recall: 0.9424 - val_accuracy: 0.9313 - val_loss: 1.4640 - val_precision: 0.9373 - val_recall: 0.9300
# Epoch 47/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 504ms/step - accuracy: 0.9472 - loss: 1.3732 - precision: 0.9556 - recall: 0.9394 - val_accuracy: 0.9326 - val_loss: 1.4446 - val_precision: 0.9360 - val_recall: 0.9300
# Epoch 48/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 506ms/step - accuracy: 0.9433 - loss: 1.3551 - precision: 0.9497 - recall: 0.9339 - val_accuracy: 0.9442 - val_loss: 1.4207 - val_precision: 0.9452 - val_recall: 0.9390
# Epoch 49/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.9542 - loss: 1.3091 - precision: 0.9623 - recall: 0.9469 - val_accuracy: 0.9339 - val_loss: 1.4296 - val_precision: 0.9386 - val_recall: 0.9313
# Epoch 50/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 513ms/step - accuracy: 0.9526 - loss: 1.2849 - precision: 0.9593 - recall: 0.9477 - val_accuracy: 0.9390 - val_loss: 1.3840 - val_precision: 0.9402 - val_recall: 0.9377
# Epoch 51/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.9562 - loss: 1.2765 - precision: 0.9629 - recall: 0.9526 - val_accuracy: 0.9429 - val_loss: 1.3634 - val_precision: 0.9452 - val_recall: 0.9390
# Epoch 52/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9619 - loss: 1.2262 - precision: 0.9668 - recall: 0.9574 - val_accuracy: 0.9442 - val_loss: 1.3488 - val_precision: 0.9465 - val_recall: 0.9416
# Epoch 53/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.9542 - loss: 1.2705 - precision: 0.9601 - recall: 0.9485 - val_accuracy: 0.9390 - val_loss: 1.3320 - val_precision: 0.9402 - val_recall: 0.9377
# Epoch 54/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 514ms/step - accuracy: 0.9601 - loss: 1.2515 - precision: 0.9640 - recall: 0.9552 - val_accuracy: 0.9468 - val_loss: 1.3110 - val_precision: 0.9478 - val_recall: 0.9429
# Epoch 55/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.9575 - loss: 1.2622 - precision: 0.9641 - recall: 0.9493 - val_accuracy: 0.9442 - val_loss: 1.3138 - val_precision: 0.9453 - val_recall: 0.9416
# Epoch 56/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 504ms/step - accuracy: 0.9572 - loss: 1.2282 - precision: 0.9641 - recall: 0.9497 - val_accuracy: 0.9364 - val_loss: 1.3237 - val_precision: 0.9399 - val_recall: 0.9326
# Epoch 57/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.9605 - loss: 1.1792 - precision: 0.9661 - recall: 0.9563 - val_accuracy: 0.9351 - val_loss: 1.2994 - val_precision: 0.9363 - val_recall: 0.9339
# Epoch 58/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.9565 - loss: 1.1720 - precision: 0.9605 - recall: 0.9515 - val_accuracy: 0.9403 - val_loss: 1.2855 - val_precision: 0.9403 - val_recall: 0.9390
# Epoch 59/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 506ms/step - accuracy: 0.9543 - loss: 1.1633 - precision: 0.9601 - recall: 0.9506 - val_accuracy: 0.9377 - val_loss: 1.2782 - val_precision: 0.9387 - val_recall: 0.9339
# Epoch 60/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 506ms/step - accuracy: 0.9700 - loss: 1.1240 - precision: 0.9759 - recall: 0.9651 - val_accuracy: 0.9326 - val_loss: 1.2833 - val_precision: 0.9349 - val_recall: 0.9313
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 0.9417 - loss: 1.2568 - precision: 0.9456 - recall: 0.9409
#
# 💾 Modelo salvo Fold 2
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 📁 Treinando Fold 3...
#
# Found 3082 validated image filenames belonging to 6 classes.
# Found 771 validated image filenames belonging to 6 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 517ms/step - accuracy: 0.9378 - loss: 1.1839 - precision: 0.9451 - recall: 0.9331 - val_accuracy: 0.9987 - val_loss: 1.0190 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 2/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.9472 - loss: 1.1464 - precision: 0.9527 - recall: 0.9384 - val_accuracy: 0.9987 - val_loss: 1.0060 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 3/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9443 - loss: 1.2021 - precision: 0.9522 - recall: 0.9376 - val_accuracy: 0.9961 - val_loss: 0.9967 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 4/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.9528 - loss: 1.1284 - precision: 0.9585 - recall: 0.9480 - val_accuracy: 0.9974 - val_loss: 0.9867 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 5/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9540 - loss: 1.1161 - precision: 0.9602 - recall: 0.9511 - val_accuracy: 0.9974 - val_loss: 0.9798 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 6/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9507 - loss: 1.1104 - precision: 0.9530 - recall: 0.9489 - val_accuracy: 0.9974 - val_loss: 0.9647 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 7/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.9468 - loss: 1.0998 - precision: 0.9538 - recall: 0.9412 - val_accuracy: 0.9948 - val_loss: 0.9596 - val_precision: 0.9948 - val_recall: 0.9948
# Epoch 8/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 512ms/step - accuracy: 0.9569 - loss: 1.0624 - precision: 0.9614 - recall: 0.9530 - val_accuracy: 0.9961 - val_loss: 0.9442 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 9/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 506ms/step - accuracy: 0.9561 - loss: 1.0501 - precision: 0.9631 - recall: 0.9521 - val_accuracy: 0.9987 - val_loss: 0.9358 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 10/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.9560 - loss: 1.0332 - precision: 0.9613 - recall: 0.9492 - val_accuracy: 0.9974 - val_loss: 0.9253 - val_precision: 0.9974 - val_recall: 0.9961
# Epoch 11/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.9569 - loss: 1.0062 - precision: 0.9627 - recall: 0.9532 - val_accuracy: 0.9974 - val_loss: 0.9091 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 12/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 511ms/step - accuracy: 0.9525 - loss: 1.0121 - precision: 0.9582 - recall: 0.9459 - val_accuracy: 0.9974 - val_loss: 0.9014 - val_precision: 0.9987 - val_recall: 0.9974
# Epoch 13/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 506ms/step - accuracy: 0.9555 - loss: 0.9980 - precision: 0.9628 - recall: 0.9518 - val_accuracy: 0.9974 - val_loss: 0.8878 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 14/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.9618 - loss: 0.9802 - precision: 0.9657 - recall: 0.9574 - val_accuracy: 0.9987 - val_loss: 0.8745 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 15/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 514ms/step - accuracy: 0.9589 - loss: 0.9796 - precision: 0.9648 - recall: 0.9545 - val_accuracy: 0.9974 - val_loss: 0.8662 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 16/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.9689 - loss: 0.9344 - precision: 0.9700 - recall: 0.9650 - val_accuracy: 0.9987 - val_loss: 0.8534 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 17/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.9646 - loss: 0.9240 - precision: 0.9681 - recall: 0.9615 - val_accuracy: 0.9961 - val_loss: 0.8438 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 18/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 500ms/step - accuracy: 0.9550 - loss: 0.9585 - precision: 0.9591 - recall: 0.9524 - val_accuracy: 0.9935 - val_loss: 0.8352 - val_precision: 0.9935 - val_recall: 0.9935
# Epoch 19/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.9667 - loss: 0.9500 - precision: 0.9673 - recall: 0.9634 - val_accuracy: 0.9961 - val_loss: 0.8236 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 20/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 503ms/step - accuracy: 0.9657 - loss: 0.9146 - precision: 0.9700 - recall: 0.9627 - val_accuracy: 0.9961 - val_loss: 0.8145 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 21/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9719 - loss: 0.8684 - precision: 0.9742 - recall: 0.9689 - val_accuracy: 0.9974 - val_loss: 0.8035 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 22/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.9625 - loss: 0.9010 - precision: 0.9655 - recall: 0.9603 - val_accuracy: 0.9987 - val_loss: 0.7938 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 23/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9576 - loss: 0.8994 - precision: 0.9636 - recall: 0.9556 - val_accuracy: 0.9974 - val_loss: 0.7812 - val_precision: 0.9987 - val_recall: 0.9974
# Epoch 24/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.9679 - loss: 0.8529 - precision: 0.9710 - recall: 0.9660 - val_accuracy: 0.9974 - val_loss: 0.7761 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 25/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9598 - loss: 0.8836 - precision: 0.9641 - recall: 0.9567 - val_accuracy: 0.9987 - val_loss: 0.7626 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 26/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 512ms/step - accuracy: 0.9668 - loss: 0.8459 - precision: 0.9691 - recall: 0.9629 - val_accuracy: 0.9974 - val_loss: 0.7561 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 27/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.9542 - loss: 0.8699 - precision: 0.9627 - recall: 0.9520 - val_accuracy: 0.9987 - val_loss: 0.7431 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 28/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.9656 - loss: 0.8226 - precision: 0.9712 - recall: 0.9635 - val_accuracy: 0.9974 - val_loss: 0.7376 - val_precision: 0.9974 - val_recall: 0.9961
# Epoch 29/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 502ms/step - accuracy: 0.9682 - loss: 0.8197 - precision: 0.9719 - recall: 0.9661 - val_accuracy: 0.9974 - val_loss: 0.7297 - val_precision: 0.9974 - val_recall: 0.9961
# Epoch 30/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 503ms/step - accuracy: 0.9710 - loss: 0.7852 - precision: 0.9754 - recall: 0.9688 - val_accuracy: 0.9987 - val_loss: 0.7171 - val_precision: 1.0000 - val_recall: 0.9987
# Epoch 31/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.9728 - loss: 0.7831 - precision: 0.9764 - recall: 0.9685 - val_accuracy: 0.9974 - val_loss: 0.7096 - val_precision: 0.9987 - val_recall: 0.9974
# Epoch 32/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.9696 - loss: 0.7875 - precision: 0.9733 - recall: 0.9683 - val_accuracy: 0.9974 - val_loss: 0.6992 - val_precision: 0.9974 - val_recall: 0.9961
# Epoch 33/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.9700 - loss: 0.7789 - precision: 0.9734 - recall: 0.9679 - val_accuracy: 0.9948 - val_loss: 0.6945 - val_precision: 0.9948 - val_recall: 0.9948
# Epoch 34/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9639 - loss: 0.7716 - precision: 0.9677 - recall: 0.9615 - val_accuracy: 0.9896 - val_loss: 0.6948 - val_precision: 0.9896 - val_recall: 0.9896
# Epoch 35/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 506ms/step - accuracy: 0.9662 - loss: 0.7625 - precision: 0.9704 - recall: 0.9662 - val_accuracy: 0.9922 - val_loss: 0.6811 - val_precision: 0.9922 - val_recall: 0.9922
# Epoch 36/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.9598 - loss: 0.7719 - precision: 0.9647 - recall: 0.9560 - val_accuracy: 0.9935 - val_loss: 0.6680 - val_precision: 0.9961 - val_recall: 0.9935
# Epoch 37/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.9759 - loss: 0.7154 - precision: 0.9772 - recall: 0.9743 - val_accuracy: 0.9909 - val_loss: 0.6664 - val_precision: 0.9922 - val_recall: 0.9909
# Epoch 38/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9734 - loss: 0.7177 - precision: 0.9774 - recall: 0.9703 - val_accuracy: 0.9948 - val_loss: 0.6500 - val_precision: 0.9948 - val_recall: 0.9948
# Epoch 39/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.9749 - loss: 0.7286 - precision: 0.9761 - recall: 0.9696 - val_accuracy: 0.9961 - val_loss: 0.6419 - val_precision: 0.9974 - val_recall: 0.9961
# Epoch 40/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.9755 - loss: 0.6957 - precision: 0.9792 - recall: 0.9712 - val_accuracy: 0.9948 - val_loss: 0.6326 - val_precision: 0.9948 - val_recall: 0.9948
# Epoch 41/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.9780 - loss: 0.6734 - precision: 0.9810 - recall: 0.9716 - val_accuracy: 0.9935 - val_loss: 0.6327 - val_precision: 0.9935 - val_recall: 0.9935
# Epoch 42/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.9757 - loss: 0.6939 - precision: 0.9791 - recall: 0.9726 - val_accuracy: 0.9883 - val_loss: 0.6331 - val_precision: 0.9896 - val_recall: 0.9870
# Epoch 43/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 513ms/step - accuracy: 0.9781 - loss: 0.6677 - precision: 0.9802 - recall: 0.9751 - val_accuracy: 0.9922 - val_loss: 0.6162 - val_precision: 0.9922 - val_recall: 0.9922
# Epoch 44/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.9747 - loss: 0.6643 - precision: 0.9768 - recall: 0.9738 - val_accuracy: 0.9961 - val_loss: 0.6006 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 45/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9793 - loss: 0.6633 - precision: 0.9816 - recall: 0.9771 - val_accuracy: 0.9974 - val_loss: 0.5907 - val_precision: 0.9987 - val_recall: 0.9974
# Epoch 46/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.9805 - loss: 0.6243 - precision: 0.9848 - recall: 0.9782 - val_accuracy: 0.9961 - val_loss: 0.5861 - val_precision: 0.9974 - val_recall: 0.9948
# Epoch 47/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 504ms/step - accuracy: 0.9762 - loss: 0.6349 - precision: 0.9786 - recall: 0.9747 - val_accuracy: 0.9961 - val_loss: 0.5782 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 48/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9794 - loss: 0.6152 - precision: 0.9812 - recall: 0.9756 - val_accuracy: 0.9974 - val_loss: 0.5629 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 49/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.9822 - loss: 0.6206 - precision: 0.9855 - recall: 0.9807 - val_accuracy: 0.9948 - val_loss: 0.5585 - val_precision: 0.9948 - val_recall: 0.9948
# Epoch 50/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.9742 - loss: 0.6165 - precision: 0.9755 - recall: 0.9726 - val_accuracy: 0.9935 - val_loss: 0.5528 - val_precision: 0.9935 - val_recall: 0.9935
# Epoch 51/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 504ms/step - accuracy: 0.9773 - loss: 0.5931 - precision: 0.9788 - recall: 0.9753 - val_accuracy: 0.9935 - val_loss: 0.5455 - val_precision: 0.9935 - val_recall: 0.9935
# Epoch 52/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.9822 - loss: 0.5820 - precision: 0.9853 - recall: 0.9803 - val_accuracy: 0.9948 - val_loss: 0.5424 - val_precision: 0.9948 - val_recall: 0.9948
# Epoch 53/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 506ms/step - accuracy: 0.9846 - loss: 0.5670 - precision: 0.9884 - recall: 0.9831 - val_accuracy: 0.9935 - val_loss: 0.5346 - val_precision: 0.9935 - val_recall: 0.9909
# Epoch 54/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.9757 - loss: 0.5849 - precision: 0.9767 - recall: 0.9730 - val_accuracy: 0.9909 - val_loss: 0.5333 - val_precision: 0.9922 - val_recall: 0.9896
# Epoch 55/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.9807 - loss: 0.5603 - precision: 0.9823 - recall: 0.9790 - val_accuracy: 0.9922 - val_loss: 0.5202 - val_precision: 0.9922 - val_recall: 0.9922
# Epoch 56/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 513ms/step - accuracy: 0.9823 - loss: 0.5519 - precision: 0.9834 - recall: 0.9818 - val_accuracy: 0.9961 - val_loss: 0.5080 - val_precision: 0.9961 - val_recall: 0.9935
# Epoch 57/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.9802 - loss: 0.5571 - precision: 0.9813 - recall: 0.9770 - val_accuracy: 0.9935 - val_loss: 0.5021 - val_precision: 0.9935 - val_recall: 0.9935
# Epoch 58/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 509ms/step - accuracy: 0.9731 - loss: 0.5766 - precision: 0.9752 - recall: 0.9719 - val_accuracy: 0.9961 - val_loss: 0.4924 - val_precision: 0.9974 - val_recall: 0.9961
# Epoch 59/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 512ms/step - accuracy: 0.9848 - loss: 0.5342 - precision: 0.9860 - recall: 0.9812 - val_accuracy: 0.9974 - val_loss: 0.4879 - val_precision: 0.9974 - val_recall: 0.9961
# Epoch 60/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 508ms/step - accuracy: 0.9756 - loss: 0.5638 - precision: 0.9785 - recall: 0.9721 - val_accuracy: 0.9870 - val_loss: 0.4925 - val_precision: 0.9896 - val_recall: 0.9857
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.9912 - loss: 0.4884 - precision: 0.9918 - recall: 0.9906
#
# 💾 Modelo salvo Fold 3
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 📁 Treinando Fold 4...
#
# Found 3083 validated image filenames belonging to 6 classes.
# Found 770 validated image filenames belonging to 6 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 88s 910ms/step - accuracy: 0.9671 - loss: 0.5408 - precision: 0.9715 - recall: 0.9653 - val_accuracy: 0.9987 - val_loss: 0.4648 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 2/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 48s 498ms/step - accuracy: 0.9765 - loss: 0.5297 - precision: 0.9787 - recall: 0.9716 - val_accuracy: 0.9987 - val_loss: 0.4594 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 3/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 504ms/step - accuracy: 0.9711 - loss: 0.5318 - precision: 0.9732 - recall: 0.9706 - val_accuracy: 0.9974 - val_loss: 0.4567 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 4/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 504ms/step - accuracy: 0.9738 - loss: 0.5333 - precision: 0.9758 - recall: 0.9728 - val_accuracy: 0.9987 - val_loss: 0.4507 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 5/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 512ms/step - accuracy: 0.9716 - loss: 0.5133 - precision: 0.9724 - recall: 0.9685 - val_accuracy: 0.9974 - val_loss: 0.4453 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 6/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 507ms/step - accuracy: 0.9814 - loss: 0.4829 - precision: 0.9851 - recall: 0.9781 - val_accuracy: 0.9974 - val_loss: 0.4379 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 7/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.9770 - loss: 0.5075 - precision: 0.9797 - recall: 0.9743 - val_accuracy: 0.9974 - val_loss: 0.4378 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 8/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 513ms/step - accuracy: 0.9770 - loss: 0.5054 - precision: 0.9783 - recall: 0.9708 - val_accuracy: 0.9974 - val_loss: 0.4373 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 9/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 510ms/step - accuracy: 0.9752 - loss: 0.4897 - precision: 0.9790 - recall: 0.9733 - val_accuracy: 0.9987 - val_loss: 0.4264 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 10/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 512ms/step - accuracy: 0.9775 - loss: 0.4794 - precision: 0.9797 - recall: 0.9766 - val_accuracy: 0.9987 - val_loss: 0.4185 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 11/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 510ms/step - accuracy: 0.9805 - loss: 0.4662 - precision: 0.9822 - recall: 0.9778 - val_accuracy: 0.9987 - val_loss: 0.4107 - val_precision: 0.9987 - val_recall: 0.9974
# Epoch 12/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 513ms/step - accuracy: 0.9816 - loss: 0.4590 - precision: 0.9830 - recall: 0.9806 - val_accuracy: 0.9974 - val_loss: 0.4104 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 13/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 501ms/step - accuracy: 0.9790 - loss: 0.4544 - precision: 0.9796 - recall: 0.9757 - val_accuracy: 0.9974 - val_loss: 0.3994 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 14/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 499ms/step - accuracy: 0.9734 - loss: 0.4595 - precision: 0.9756 - recall: 0.9705 - val_accuracy: 0.9974 - val_loss: 0.3974 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 15/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.9844 - loss: 0.4384 - precision: 0.9846 - recall: 0.9817 - val_accuracy: 0.9974 - val_loss: 0.3944 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 16/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.9734 - loss: 0.4398 - precision: 0.9770 - recall: 0.9705 - val_accuracy: 0.9987 - val_loss: 0.3845 - val_precision: 0.9987 - val_recall: 0.9974
# Epoch 17/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 50s 511ms/step - accuracy: 0.9792 - loss: 0.4557 - precision: 0.9811 - recall: 0.9788 - val_accuracy: 0.9974 - val_loss: 0.3807 - val_precision: 0.9987 - val_recall: 0.9974
# Epoch 18/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 49s 505ms/step - accuracy: 0.9815 - loss: 0.4428 - precision: 0.9842 - recall: 0.9791 - val_accuracy: 0.9987 - val_loss: 0.3748 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 19/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 483ms/step - accuracy: 0.9796 - loss: 0.4278 - precision: 0.9827 - recall: 0.9768 - val_accuracy: 0.9961 - val_loss: 0.3703 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 20/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 481ms/step - accuracy: 0.9718 - loss: 0.4458 - precision: 0.9745 - recall: 0.9678 - val_accuracy: 0.9987 - val_loss: 0.3666 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 21/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 476ms/step - accuracy: 0.9785 - loss: 0.4095 - precision: 0.9823 - recall: 0.9758 - val_accuracy: 0.9987 - val_loss: 0.3597 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 22/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 474ms/step - accuracy: 0.9858 - loss: 0.4008 - precision: 0.9880 - recall: 0.9843 - val_accuracy: 0.9974 - val_loss: 0.3552 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 23/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 482ms/step - accuracy: 0.9839 - loss: 0.3868 - precision: 0.9859 - recall: 0.9827 - val_accuracy: 0.9974 - val_loss: 0.3564 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 24/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9793 - loss: 0.3980 - precision: 0.9820 - recall: 0.9765 - val_accuracy: 0.9987 - val_loss: 0.3492 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 25/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9712 - loss: 0.4038 - precision: 0.9775 - recall: 0.9674 - val_accuracy: 0.9987 - val_loss: 0.3403 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 26/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 476ms/step - accuracy: 0.9862 - loss: 0.3833 - precision: 0.9884 - recall: 0.9837 - val_accuracy: 0.9987 - val_loss: 0.3360 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 27/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9828 - loss: 0.3817 - precision: 0.9838 - recall: 0.9799 - val_accuracy: 1.0000 - val_loss: 0.3298 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 28/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9816 - loss: 0.3757 - precision: 0.9829 - recall: 0.9792 - val_accuracy: 0.9974 - val_loss: 0.3294 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 29/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 476ms/step - accuracy: 0.9806 - loss: 0.3833 - precision: 0.9813 - recall: 0.9780 - val_accuracy: 0.9987 - val_loss: 0.3239 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 30/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 476ms/step - accuracy: 0.9867 - loss: 0.3641 - precision: 0.9880 - recall: 0.9854 - val_accuracy: 0.9974 - val_loss: 0.3225 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 31/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 480ms/step - accuracy: 0.9834 - loss: 0.3909 - precision: 0.9850 - recall: 0.9809 - val_accuracy: 0.9961 - val_loss: 0.3165 - val_precision: 0.9974 - val_recall: 0.9961
# Epoch 32/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9789 - loss: 0.3650 - precision: 0.9845 - recall: 0.9782 - val_accuracy: 0.9974 - val_loss: 0.3142 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 33/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 472ms/step - accuracy: 0.9855 - loss: 0.3478 - precision: 0.9865 - recall: 0.9826 - val_accuracy: 0.9961 - val_loss: 0.3096 - val_precision: 0.9974 - val_recall: 0.9961
# Epoch 34/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 476ms/step - accuracy: 0.9817 - loss: 0.3475 - precision: 0.9846 - recall: 0.9780 - val_accuracy: 0.9974 - val_loss: 0.3080 - val_precision: 0.9974 - val_recall: 0.9961
# Epoch 35/60
# ...
# Epoch 51/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 475ms/step - accuracy: 0.9892 - loss: 0.2742 - precision: 0.9900 - recall: 0.9868 - val_accuracy: 0.9974 - val_loss: 0.2462 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 52/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 473ms/step - accuracy: 0.9854 - loss: 0.2832 - precision: 0.9862 - recall: 0.9844 - val_accuracy: 0.9948 - val_loss: 0.2427 - val_precision: 0.9961 - val_recall: 0.9948
# Epoch 53/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 474ms/step - accuracy: 0.9894 - loss: 0.2650 - precision: 0.9899 - recall: 0.9872 - val_accuracy: 0.9948 - val_loss: 0.2447 - val_precision: 0.9961 - val_recall: 0.9948
# Epoch 54/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9885 - loss: 0.2653 - precision: 0.9903 - recall: 0.9865 - val_accuracy: 0.9961 - val_loss: 0.2414 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 55/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 471ms/step - accuracy: 0.9866 - loss: 0.2728 - precision: 0.9870 - recall: 0.9832 - val_accuracy: 0.9935 - val_loss: 0.2445 - val_precision: 0.9935 - val_recall: 0.9922
# Epoch 56/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 475ms/step - accuracy: 0.9838 - loss: 0.2764 - precision: 0.9849 - recall: 0.9825 - val_accuracy: 0.9935 - val_loss: 0.2417 - val_precision: 0.9935 - val_recall: 0.9935
# Epoch 57/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 479ms/step - accuracy: 0.9874 - loss: 0.2603 - precision: 0.9878 - recall: 0.9862 - val_accuracy: 0.9948 - val_loss: 0.2343 - val_precision: 0.9961 - val_recall: 0.9948
# Epoch 58/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 472ms/step - accuracy: 0.9902 - loss: 0.2471 - precision: 0.9908 - recall: 0.9881 - val_accuracy: 0.9961 - val_loss: 0.2303 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 59/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 475ms/step - accuracy: 0.9848 - loss: 0.2512 - precision: 0.9855 - recall: 0.9843 - val_accuracy: 0.9935 - val_loss: 0.2353 - val_precision: 0.9948 - val_recall: 0.9935
# Epoch 60/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 480ms/step - accuracy: 0.9879 - loss: 0.2469 - precision: 0.9879 - recall: 0.9877 - val_accuracy: 0.9935 - val_loss: 0.2238 - val_precision: 0.9935 - val_recall: 0.9935
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.9934 - loss: 0.2245 - precision: 0.9934 - recall: 0.9934
#
# 💾 Modelo salvo Fold 4
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step
# 📁 Treinando Fold 5...
#
# Found 3083 validated image filenames belonging to 6 classes.
# Found 770 validated image filenames belonging to 6 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 483ms/step - accuracy: 0.9842 - loss: 0.2525 - precision: 0.9863 - recall: 0.9828 - val_accuracy: 0.9987 - val_loss: 0.2140 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 2/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 474ms/step - accuracy: 0.9765 - loss: 0.2697 - precision: 0.9772 - recall: 0.9757 - val_accuracy: 0.9987 - val_loss: 0.2109 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 3/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 476ms/step - accuracy: 0.9773 - loss: 0.2571 - precision: 0.9821 - recall: 0.9762 - val_accuracy: 0.9974 - val_loss: 0.2078 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 4/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 473ms/step - accuracy: 0.9846 - loss: 0.2461 - precision: 0.9863 - recall: 0.9840 - val_accuracy: 0.9987 - val_loss: 0.2073 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 5/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 486ms/step - accuracy: 0.9889 - loss: 0.2381 - precision: 0.9889 - recall: 0.9880 - val_accuracy: 1.0000 - val_loss: 0.2011 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 6/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 480ms/step - accuracy: 0.9820 - loss: 0.2387 - precision: 0.9845 - recall: 0.9800 - val_accuracy: 0.9974 - val_loss: 0.2055 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 7/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 472ms/step - accuracy: 0.9854 - loss: 0.2443 - precision: 0.9871 - recall: 0.9849 - val_accuracy: 0.9987 - val_loss: 0.1972 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 8/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 478ms/step - accuracy: 0.9848 - loss: 0.2342 - precision: 0.9886 - recall: 0.9832 - val_accuracy: 0.9987 - val_loss: 0.1956 - val_precision: 1.0000 - val_recall: 0.9987
# Epoch 9/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9864 - loss: 0.2292 - precision: 0.9878 - recall: 0.9857 - val_accuracy: 1.0000 - val_loss: 0.1937 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 10/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 478ms/step - accuracy: 0.9849 - loss: 0.2334 - precision: 0.9888 - recall: 0.9835 - val_accuracy: 0.9974 - val_loss: 0.1950 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 11/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 475ms/step - accuracy: 0.9865 - loss: 0.2220 - precision: 0.9880 - recall: 0.9852 - val_accuracy: 0.9987 - val_loss: 0.1933 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 12/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 479ms/step - accuracy: 0.9909 - loss: 0.2148 - precision: 0.9926 - recall: 0.9895 - val_accuracy: 0.9974 - val_loss: 0.1910 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 13/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 474ms/step - accuracy: 0.9878 - loss: 0.2176 - precision: 0.9899 - recall: 0.9860 - val_accuracy: 1.0000 - val_loss: 0.1848 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 14/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 475ms/step - accuracy: 0.9851 - loss: 0.2361 - precision: 0.9863 - recall: 0.9846 - val_accuracy: 0.9974 - val_loss: 0.1849 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 15/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 474ms/step - accuracy: 0.9899 - loss: 0.2200 - precision: 0.9907 - recall: 0.9883 - val_accuracy: 0.9974 - val_loss: 0.1843 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 16/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 484ms/step - accuracy: 0.9890 - loss: 0.2148 - precision: 0.9890 - recall: 0.9878 - val_accuracy: 0.9987 - val_loss: 0.1812 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 17/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 474ms/step - accuracy: 0.9774 - loss: 0.2378 - precision: 0.9802 - recall: 0.9753 - val_accuracy: 0.9961 - val_loss: 0.1810 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 18/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9856 - loss: 0.2189 - precision: 0.9865 - recall: 0.9849 - val_accuracy: 0.9961 - val_loss: 0.1819 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 19/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 475ms/step - accuracy: 0.9880 - loss: 0.2051 - precision: 0.9890 - recall: 0.9858 - val_accuracy: 0.9974 - val_loss: 0.1757 - val_precision: 0.9974 - val_recall: 0.9961
# Epoch 20/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 478ms/step - accuracy: 0.9870 - loss: 0.2088 - precision: 0.9875 - recall: 0.9837 - val_accuracy: 0.9974 - val_loss: 0.1769 - val_precision: 0.9974 - val_recall: 0.9961
# Epoch 21/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 474ms/step - accuracy: 0.9896 - loss: 0.2046 - precision: 0.9903 - recall: 0.9883 - val_accuracy: 0.9974 - val_loss: 0.1730 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 22/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9878 - loss: 0.2150 - precision: 0.9899 - recall: 0.9856 - val_accuracy: 1.0000 - val_loss: 0.1671 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 23/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 487ms/step - accuracy: 0.9887 - loss: 0.1936 - precision: 0.9916 - recall: 0.9869 - val_accuracy: 0.9987 - val_loss: 0.1685 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 24/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9863 - loss: 0.2055 - precision: 0.9892 - recall: 0.9850 - val_accuracy: 0.9961 - val_loss: 0.1687 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 25/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9797 - loss: 0.2341 - precision: 0.9805 - recall: 0.9781 - val_accuracy: 0.9987 - val_loss: 0.1633 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 26/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 474ms/step - accuracy: 0.9911 - loss: 0.1895 - precision: 0.9918 - recall: 0.9870 - val_accuracy: 0.9987 - val_loss: 0.1612 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 27/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9903 - loss: 0.1904 - precision: 0.9907 - recall: 0.9897 - val_accuracy: 1.0000 - val_loss: 0.1588 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 28/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 478ms/step - accuracy: 0.9890 - loss: 0.1834 - precision: 0.9911 - recall: 0.9887 - val_accuracy: 0.9974 - val_loss: 0.1614 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 29/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 474ms/step - accuracy: 0.9903 - loss: 0.1783 - precision: 0.9904 - recall: 0.9899 - val_accuracy: 0.9948 - val_loss: 0.1634 - val_precision: 0.9948 - val_recall: 0.9948
# Epoch 30/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 481ms/step - accuracy: 0.9870 - loss: 0.1854 - precision: 0.9881 - recall: 0.9861 - val_accuracy: 0.9987 - val_loss: 0.1590 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 31/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9869 - loss: 0.1986 - precision: 0.9870 - recall: 0.9858 - val_accuracy: 0.9974 - val_loss: 0.1580 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 32/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 475ms/step - accuracy: 0.9912 - loss: 0.1769 - precision: 0.9930 - recall: 0.9892 - val_accuracy: 0.9974 - val_loss: 0.1540 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 33/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 478ms/step - accuracy: 0.9880 - loss: 0.1799 - precision: 0.9886 - recall: 0.9865 - val_accuracy: 1.0000 - val_loss: 0.1512 - val_precision: 1.0000 - val_recall: 0.9987
# Epoch 34/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 481ms/step - accuracy: 0.9876 - loss: 0.1972 - precision: 0.9887 - recall: 0.9862 - val_accuracy: 0.9961 - val_loss: 0.1542 - val_precision: 0.9961 - val_recall: 0.9948
# Epoch 35/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 479ms/step - accuracy: 0.9884 - loss: 0.1716 - precision: 0.9889 - recall: 0.9884 - val_accuracy: 0.9987 - val_loss: 0.1482 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 36/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9924 - loss: 0.1740 - precision: 0.9933 - recall: 0.9913 - val_accuracy: 1.0000 - val_loss: 0.1456 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 37/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 479ms/step - accuracy: 0.9898 - loss: 0.1850 - precision: 0.9927 - recall: 0.9876 - val_accuracy: 0.9948 - val_loss: 0.1490 - val_precision: 0.9948 - val_recall: 0.9948
# Epoch 38/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 478ms/step - accuracy: 0.9912 - loss: 0.1701 - precision: 0.9917 - recall: 0.9908 - val_accuracy: 0.9987 - val_loss: 0.1447 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 39/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 475ms/step - accuracy: 0.9924 - loss: 0.1655 - precision: 0.9936 - recall: 0.9907 - val_accuracy: 0.9987 - val_loss: 0.1415 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 40/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 476ms/step - accuracy: 0.9823 - loss: 0.1835 - precision: 0.9842 - recall: 0.9815 - val_accuracy: 0.9948 - val_loss: 0.1486 - val_precision: 0.9948 - val_recall: 0.9948
# Epoch 41/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 478ms/step - accuracy: 0.9904 - loss: 0.1654 - precision: 0.9912 - recall: 0.9892 - val_accuracy: 0.9987 - val_loss: 0.1405 - val_precision: 1.0000 - val_recall: 0.9987
# Epoch 42/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 473ms/step - accuracy: 0.9902 - loss: 0.1635 - precision: 0.9908 - recall: 0.9879 - val_accuracy: 0.9948 - val_loss: 0.1425 - val_precision: 0.9948 - val_recall: 0.9948
# Epoch 43/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 480ms/step - accuracy: 0.9905 - loss: 0.1579 - precision: 0.9916 - recall: 0.9896 - val_accuracy: 0.9935 - val_loss: 0.1404 - val_precision: 0.9948 - val_recall: 0.9935
# Epoch 44/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 478ms/step - accuracy: 0.9845 - loss: 0.1900 - precision: 0.9869 - recall: 0.9827 - val_accuracy: 0.9987 - val_loss: 0.1354 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 45/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 478ms/step - accuracy: 0.9906 - loss: 0.1829 - precision: 0.9907 - recall: 0.9897 - val_accuracy: 0.9974 - val_loss: 0.1358 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 46/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9871 - loss: 0.1566 - precision: 0.9886 - recall: 0.9867 - val_accuracy: 0.9961 - val_loss: 0.1385 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 47/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 478ms/step - accuracy: 0.9911 - loss: 0.1527 - precision: 0.9927 - recall: 0.9901 - val_accuracy: 0.9974 - val_loss: 0.1339 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 48/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 479ms/step - accuracy: 0.9874 - loss: 0.1582 - precision: 0.9892 - recall: 0.9874 - val_accuracy: 0.9935 - val_loss: 0.1360 - val_precision: 0.9935 - val_recall: 0.9935
# Epoch 49/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 481ms/step - accuracy: 0.9888 - loss: 0.1547 - precision: 0.9898 - recall: 0.9882 - val_accuracy: 0.9974 - val_loss: 0.1322 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 50/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 478ms/step - accuracy: 0.9912 - loss: 0.1482 - precision: 0.9912 - recall: 0.9904 - val_accuracy: 0.9961 - val_loss: 0.1326 - val_precision: 0.9961 - val_recall: 0.9961
# Epoch 51/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 484ms/step - accuracy: 0.9908 - loss: 0.1572 - precision: 0.9908 - recall: 0.9907 - val_accuracy: 0.9974 - val_loss: 0.1288 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 52/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 483ms/step - accuracy: 0.9946 - loss: 0.1428 - precision: 0.9946 - recall: 0.9923 - val_accuracy: 0.9974 - val_loss: 0.1288 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 53/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 485ms/step - accuracy: 0.9877 - loss: 0.1492 - precision: 0.9892 - recall: 0.9871 - val_accuracy: 0.9987 - val_loss: 0.1221 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 54/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 479ms/step - accuracy: 0.9922 - loss: 0.1415 - precision: 0.9923 - recall: 0.9917 - val_accuracy: 0.9987 - val_loss: 0.1207 - val_precision: 0.9987 - val_recall: 0.9987
# Epoch 55/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 478ms/step - accuracy: 0.9945 - loss: 0.1395 - precision: 0.9945 - recall: 0.9933 - val_accuracy: 1.0000 - val_loss: 0.1186 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 56/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 486ms/step - accuracy: 0.9921 - loss: 0.1379 - precision: 0.9928 - recall: 0.9917 - val_accuracy: 0.9948 - val_loss: 0.1249 - val_precision: 0.9961 - val_recall: 0.9948
# Epoch 57/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 477ms/step - accuracy: 0.9900 - loss: 0.1398 - precision: 0.9909 - recall: 0.9882 - val_accuracy: 0.9974 - val_loss: 0.1226 - val_precision: 0.9974 - val_recall: 0.9974
# Epoch 58/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 481ms/step - accuracy: 0.9943 - loss: 0.1304 - precision: 0.9956 - recall: 0.9927 - val_accuracy: 1.0000 - val_loss: 0.1161 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 59/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 476ms/step - accuracy: 0.9912 - loss: 0.1322 - precision: 0.9922 - recall: 0.9911 - val_accuracy: 0.9987 - val_loss: 0.1168 - val_precision: 0.9987 - val_recall: 0.9974
# Epoch 60/60
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 46s 476ms/step - accuracy: 0.9915 - loss: 0.1372 - precision: 0.9917 - recall: 0.9901 - val_accuracy: 0.9987 - val_loss: 0.1147 - val_precision: 1.0000 - val_recall: 0.9987
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9995 - loss: 0.1136 - precision: 1.0000 - recall: 0.9995
#
# 💾 Modelo salvo Fold 5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# Resultados Cross-Validation:
# Accuracy : 0.9442 ± 0.0715
# Precision: 0.9334 ± 0.0874
# Recall   : 0.9491 ± 0.0667
# F1 Score : 0.9386 ± 0.0812

# %% [markdown]
# ## 📋 Resultados Finais da Validação Cruzada

# %%
# Resultados Finais da Validação Cruzada com desvio padrão:

from sklearn.metrics import (
    roc_auc_score,
    cohen_kappa_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
import numpy as np

# Obter nomes das classes
class_names = list(val_gen.class_indices.keys())
n_classes = len(class_names)

# Inicializar listas para métricas por fold
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []
kappa_scores = []
auc_macro_scores = []
auc_scores_per_class = [[] for _ in range(n_classes)]

# Para matriz de confusão agregada
all_y_true = []
all_y_pred_classes = []
all_y_pred_probs = []

kf = KFold(n_splits=5, shuffle=True, random_state=42)
for fold, (train_idx, val_idx) in enumerate(kf.split(df)):
    print(f"\n🔍 Reavaliando Fold {fold + 1} para métricas agregadas...")

    val_df = df.iloc[val_idx]

    val_gen = validation_datagen.flow_from_dataframe(
        val_df,
        x_col='filename',
        y_col='label',
        target_size=(224, 224),
        batch_size=32,
        shuffle=False
    )

    model = tf.keras.models.load_model(f'model_fold_{fold+1}.keras')

    y_pred_prob = model.predict(val_gen)
    y_pred_class = np.argmax(y_pred_prob, axis=1)
    y_true = val_gen.classes

    # Salvar para matriz de confusão agregada
    all_y_true.append(y_true)
    all_y_pred_classes.append(y_pred_class)
    all_y_pred_probs.append(y_pred_prob)

    # Métricas por fold
    acc = accuracy_score(y_true, y_pred_class)
    prec = precision_score(y_true, y_pred_class, average='macro', zero_division=0)
    rec = recall_score(y_true, y_pred_class, average='macro', zero_division=0)
    f1 = f1_score(y_true, y_pred_class, average='macro', zero_division=0)
    kappa = cohen_kappa_score(y_true, y_pred_class)

    # AUC
    y_true_bin = label_binarize(y_true, classes=range(n_classes))
    auc_class = roc_auc_score(y_true_bin, y_pred_prob, average=None, multi_class="ovr")
    auc_macro = roc_auc_score(y_true_bin, y_pred_prob, average="macro", multi_class="ovr")

    # Salvar métricas
    accuracy_scores.append(acc)
    precision_scores.append(prec)
    recall_scores.append(rec)
    f1_scores.append(f1)
    kappa_scores.append(kappa)
    auc_macro_scores.append(auc_macro)
    for i in range(n_classes):
        auc_scores_per_class[i].append(auc_class[i])

# Concatenar para matriz de confusão agregada
all_y_true = np.concatenate(all_y_true)
all_y_pred_classes = np.concatenate(all_y_pred_classes)

# Matriz de Confusão Agregada
cm_total = confusion_matrix(all_y_true, all_y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_total, display_labels=class_names)
fig, ax = plt.subplots(figsize=(6, 6))
disp.plot(cmap='Blues', ax=ax, values_format='d')
plt.title("🧩 Matriz de Confusão Agregada (5 folds)")
plt.tight_layout()
plt.show()

# Resultados com média e desvio padrão
print("\n📊 MÉTRICAS FINAIS - CROSS-VALIDATION (5 folds):")
print(f"Accuracy         : {np.mean(accuracy_scores):.4f} ± {np.std(accuracy_scores):.4f}")
print(f"Precision (macro): {np.mean(precision_scores):.4f} ± {np.std(precision_scores):.4f}")
print(f"Recall (macro)   : {np.mean(recall_scores):.4f} ± {np.std(recall_scores):.4f}")
print(f"F1-Score (macro) : {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"Cohen’s Kappa    : {np.mean(kappa_scores):.4f} ± {np.std(kappa_scores):.4f}")
print(f"AUC-ROC (macro)  : {np.mean(auc_macro_scores):.4f} ± {np.std(auc_macro_scores):.4f}")

print("\n🎯 AUC-ROC por classe:")
for i, cls in enumerate(class_names):
    print(f"- {cls:<20}: {np.mean(auc_scores_per_class[i]):.4f} ± {np.std(auc_scores_per_class[i]):.4f}")
# Out:
# 🔍 Reavaliando Fold 1 para métricas agregadas...
# Found 771 validated image filenames belonging to 6 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 227ms/step
#
# 🔍 Reavaliando Fold 2 para métricas agregadas...
# Found 771 validated image filenames belonging to 6 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 222ms/step
#
# 🔍 Reavaliando Fold 3 para métricas agregadas...
# Found 771 validated image filenames belonging to 6 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 237ms/step
#
# 🔍 Reavaliando Fold 4 para métricas agregadas...
# Found 770 validated image filenames belonging to 6 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 231ms/step
#
# 🔍 Reavaliando Fold 5 para métricas agregadas...
# Found 770 validated image filenames belonging to 6 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 238ms/step
# /tmp/ipython-input-14-439717328.py:95: UserWarning: Glyph 129513 (\N{JIGSAW PUZZLE PIECE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129513 (\N{JIGSAW PUZZLE PIECE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 📊 MÉTRICAS FINAIS - CROSS-VALIDATION (5 folds):
# Accuracy         : 0.9442 ± 0.0715
# Precision (macro): 0.9334 ± 0.0874
# Recall (macro)   : 0.9491 ± 0.0667
# F1-Score (macro) : 0.9386 ± 0.0812
# Cohen’s Kappa    : 0.9305 ± 0.0889
# AUC-ROC (macro)  : 0.9931 ± 0.0114
#
# 🎯 AUC-ROC por classe:
# - bottle              : 0.9882 ± 0.0194
# - canister            : 0.9938 ± 0.0115
# - cans                : 0.9977 ± 0.0041
# - cardboard           : 0.9966 ± 0.0062
# - detergent           : 0.9853 ± 0.0218
# - glass               : 0.9971 ± 0.0055
